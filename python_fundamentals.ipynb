# %% [markdown]
# <a href="https://colab.research.google.com/github/SushmithaP2004/Data_science/blob/main/python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,2,3,4,5]
for num in l:
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l=[1,2,3,4,5]
for num in l:
  if(num%2==0):
   print(num**2)
# Out:
# 4
# 16

# %%
s="sushmitha"
for str in s:
  print(str)
# Out:
# s
# u
# s
# h
# m
# i
# t
# h
# a

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
  if i%2==0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
l=[10,20,30,40,50,60]
for i in range(len(l)):
  print(i,l[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60

# %%
#break is to terminate the loop
n=15
for x in range(2,n+1):
     if n%x==0:
          print(x)
          break
# Out:
# 3

# %%
i=1
while i<=5:
  if i==3:
    break
  print(i)
  i=i+1
print(i)
# Out:
# 1
# 2
# 3

# %%
#continue
